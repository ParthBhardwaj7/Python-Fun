# %% [markdown]
# Rock Or Mine Prediction- what will happen in this is that we have sonar data of submerine now we will have to train that model on the basis of data and it will then predict if mine or stone will come.
#
# Sonar data --> Data pre-process -->Train test Split --> Logistic Regression Model ko denga to train itself on that data
#
# new data -->Trained logistic Regression Model -->It will tell if it is Rock or Mine

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-dc11c40c-0b4b-4355-af81-71aa03b291dd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc11c40c-0b4b-4355-af81-71aa03b291dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# mv: cannot move 'kaggle.json' to '/root/.kaggle/': Not a directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
import os
os.environ['KAGGLE_USERNAME'] = 'parthbhardwaj9'
os.environ['KAGGLE_KEY'] = 'a2ffe995deea65a6bb2cffce17629bee'

# %%
import kaggle
# !kaggle datasets download mayurdalvi/sonar-mine-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mayurdalvi/sonar-mine-dataset
# License(s): CC0-1.0
# ...
#   0% 0.00/29.1k [00:00<?, ?B/s]
# 100% 29.1k/29.1k [00:00<00:00, 29.8MB/s]

# %%
import zipfile
import os
data='/content/sonar-mine-dataset.zip'
ext='/content/sample_data'
with zipfile.ZipFile(data,'r') as zip_ref:
  zip_ref.extractall(ext)

# %% [markdown]
# Data Pre-Processing

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
sonar=pd.read_csv('/content/sample_data/sonar data.csv',header=None)

# %%
sonar.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
sonar.shape
# Out:
# (208, 61)

# %%
sonar[60].value_counts()
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %%
sonar.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
sonar.groupby(60).mean()
# Out:
#           0         1         2         3         4         5         6   \
# 60
# M   0.034989  0.045544  0.050720  0.064768  0.086715  0.111864  0.128359
# R   0.022498  0.030303  0.035951  0.041447  0.062028  0.096224  0.114180
#
#           7         8         9   ...        50        51        52        53  \
# 60                                ...
# M   0.149832  0.213492  0.251022  ...  0.019352  0.016014  0.011643  0.012185
# R   0.117596  0.137392  0.159325  ...  0.012311  0.010453  0.009640  0.009518
#
#           54        55        56        57        58        59
# 60
# M   0.009923  0.008914  0.007825  0.009060  0.008695  0.006930
# R   0.008567  0.007430  0.007814  0.006677  0.007078  0.006024
#
# [2 rows x 60 columns]

# %%
#Separaing data and labels
X=sonar.drop(columns=60,axis=1) #column kai liya axis =1
Y=sonar[60]

# %%
print(X)
print(Y)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
#Training and test data
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1, stratify=Y,random_state=1)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (208, 60) (187, 60) (21, 60)

# %%
model=LogisticRegression()

# %%
#training the logistic regression model
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
#accuracy on the training data
X_train_prediction=model.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction,Y_train)

# %%
print('accuracy on training data:' , training_data_accuracy)
# Out:
# accuracy on training data: 0.8342245989304813

# %%
#accuracy on the training data
X_test_prediction=model.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)

# %%
print('accuracy on training data:' , test_data_accuracy)
# Out:
# accuracy on training data: 0.7619047619047619

# %% [markdown]
# Making a predictive system

# %%
input_data=(0.0453,0.0523,	0.0843	,0.0689,	0.1183,	0.2583,	0.2156,	0.3481,	0.3337,	0.2872,	0.4918,0.6552	,0.6919,	0.7797,	0.7464,	0.9444	,1.0000,	0.8874,	0.8024	,0.7818,	0.5212,	0.4052	,0.3957,	0.3914	,0.3250	,0.3200	,0.3271,	0.2767,	0.4423,	0.2028	,0.3788,	0.2947	,0.1984,	0.2341,	0.1306	,0.4182,	0.3835,	0.1057	,0.1840	,0.1970,	0.1674,	0.0583,	0.1401,	0.1628,	0.0621,	0.0203,	0.0530	,0.0742,	0.0409,	0.0061,	0.0125,	0.0084,	0.0089,	0.0048	,0.0094,	0.0191	,0.0140	,0.0049	,0.0052,	0.0044)
#changing the imput data in numpy array
input_data_as_numpy_array=np.array(input_data)
# reshape the numpy array as we are predicting for one instance
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)
prediction=model.predict(input_data_reshaped)
print(prediction)

if(prediction[0]=='R'):
  print("object is a rock")
else:
  print("it is a mine")
# Out:
# ['R']
# object is a rock

# %% [markdown]
# Work Flow for diabetes Prediction:
#
# diabetes data-->data pre processing--> train test split--> Support vector machine classifier
#
# After Training:
# trained data--> machine model-->diabetes or non diabetic

# %%
#!/bin/bash
# !kaggle datasets download akshaydattatraykhare/diabetes-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/akshaydattatraykhare/diabetes-dataset
# License(s): CC0-1.0
# ...
#   0% 0.00/8.91k [00:00<?, ?B/s]
# 100% 8.91k/8.91k [00:00<00:00, 14.0MB/s]

# %%
import zipfile
import os
data='/content/diabetes-dataset.zip'
ext='/content/sample_data'
with zipfile.ZipFile(data,'r') as zip_ref:
  zip_ref.extractall(ext)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Analysis

# %%
#loading the diabetes dataset to a pandas dataframe
daib=pd.read_csv("/content/sample_data/diabetes.csv")

# %%
pd.read_csv?

# %%
#printing the first five rows of dataset
daib.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#number of rows and columns in this dataset
daib.shape
# Out:
# (768, 9)

# %%
#getting the statistical measure of the dat
daib.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
daib['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# 0-->Non Diabetic
# 1-->diabetic

# %%
daib.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
#separaating the data and labels
X= daib.drop(columns='Outcome',axis=1)
Y=daib['Outcome']

# %%
print(X)
print(Y)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %% [markdown]
# Data Standardization

# %%
scalar=StandardScaler()

# %%
scalar.fit(X)
# Out:
# StandardScaler()

# %%
Standard=scalar.transform(X)

# %%
print(Standard)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X=Standard
Y=daib['Outcome']

# %%
print(X)
print(Y)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# Training the Model

# %%
classifier = svm.SVC(kernel='linear')

# %%
#training the support vector Machine Classifier
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# accuracy score on the training data
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.7866449511400652

# %%
# accuracy score on the training data
X_test_prediction = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score of the training data : ', test_data_accuracy)
# Out:
# Accuracy score of the training data :  0.7727272727272727

# %% [markdown]
# Making the productive system

# %%
input_data = (5,166,72,19,175,25.8,0.587,51)
# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# standardize the input data
std_data = scalar.transform(input_data_reshaped)
print(std_data)

prediction = classifier.predict(std_data)
print(prediction)

if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')
# Out:
# [[ 0.3429808   1.41167241  0.14964075 -0.09637905  0.82661621 -0.78595734
#    0.34768723  1.51108316]]
# [1]
# The person is diabetic
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Spam Mail detection :
#
# Data Collection and pre processing:it uses data.csv of mail dataset
#
# Training the model with logistic Regression
#
# mail dataset lainga ---> data ko pre process karenga(text para ko no. mai convert karta hai) --->Train test split karenga---> Logistic regression Model ko dainga Joh trained hojayaga

# %%
#!/bin/bash
# !kaggle datasets download venky73/spam-mails-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/venky73/spam-mails-dataset
# License(s): CC0-1.0
# ...
#   0% 0.00/1.86M [00:00<?, ?B/s]
# 100% 1.86M/1.86M [00:00<00:00, 91.5MB/s]

# %%
import zipfile
import os
data='/content/spam-mails-dataset.zip'
extract='/content/sample_data'
with zipfile.ZipFile(data,'r') as zip_ref:
  zip_ref.extractall(extract)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
spam=pd.read_csv('/content/sample_data/spam_ham_dataset.csv')

# %%
spam.head()
# Out:
#    Unnamed: 0 label                                               text  \
# 0         605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1        2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2        3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3        4685  spam  Subject: photoshop , windows , office . cheap ...
# 4        2030   ham  Subject: re : indian springs\r\nthis deal is t...
#
#    label_num
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0

# %%
spam.describe()
# Out:
#         Unnamed: 0    label_num
# count  5171.000000  5171.000000
# mean   2585.000000     0.289886
# std    1492.883452     0.453753
# min       0.000000     0.000000
# 25%    1292.500000     0.000000
# 50%    2585.000000     0.000000
# 75%    3877.500000     1.000000
# max    5170.000000     1.000000

# %%
spam.tail()
# Out:
#       Unnamed: 0 label                                               text  \
# 5166        1518   ham  Subject: put the 10 on the ft\r\nthe transport...
# 5167         404   ham  Subject: 3 / 4 / 2000 and following noms\r\nhp...
# 5168        2933   ham  Subject: calpine daily gas nomination\r\n>\r\n...
# 5169        1409   ham  Subject: industrial worksheets for august 2000...
# 5170        4807  spam  Subject: important online banking alert\r\ndea...
#
#       label_num
# 5166          0
# 5167          0
# 5168          0
# 5169          0
# 5170          1

# %%
spam.shape
# Out:
# (5171, 4)

# %%
X=spam['text']
Y=spam['label_num']

# %%
print(X)
print(Y)
# Out:
# 0       Subject: enron methanol ; meter # : 988291\r\n...
# 1       Subject: hpl nom for january 9 , 2001\r\n( see...
# 2       Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3       Subject: photoshop , windows , office . cheap ...
# 4       Subject: re : indian springs\r\nthis deal is t...
#                               ...
# 5166    Subject: put the 10 on the ft\r\nthe transport...
# 5167    Subject: 3 / 4 / 2000 and following noms\r\nhp...
# 5168    Subject: calpine daily gas nomination\r\n>\r\n...
# 5169    Subject: industrial worksheets for august 2000...
# 5170    Subject: important online banking alert\r\ndea...
# Name: text, Length: 5171, dtype: object
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 5166    0
# 5167    0
# 5168    0
# 5169    0
# 5170    1
# Name: label_num, Length: 5171, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=1)

# %%
print(X.shape)
print(X_train.shape)
print(X_test.shape)
spam.isnull().values.any()#it checks ki koi null value hai ya nhi
spam=spam.where((pd.notnull(spam)),'')
# Out:
# (5171,)
# (4136,)
# (1035,)

# %%
#transform the text data to feature vectors that can be used as input to the logistic regression
feature_extraction=TfidfVectorizer(min_df=1,stop_words='english',lowercase=True) # Changed 'True' to True

X_train_features = feature_extraction.fit_transform(X_train)
X_test_features = feature_extraction.transform(X_test)

# %%
print(X_train)
# Out:
# 4282           Subject: hl & p\r\nthe most recent numbers
# 2247    Subject: re : your account # bj 535\r\nhi agai...
# 32      Subject: to : all domestic employees who parti...
# 4254    Subject: re : first delivery - cummings & walk...
# 2860    Subject: aol instant messenger reconfirmation\...
#                               ...
# 2763    Subject: re [ 13 ]\r\ndriving at ? in 1876\r\n...
# 905     Subject: 29 th changes\r\n- - - - - - - - - - ...
# 3980    Subject: buy regalis , also known as superviag...
# 235     Subject: 24 x 5 products\r\nplease make sure t...
# 5157    Subject: 5 th changes @ duke and air liquide\r...
# Name: text, Length: 4136, dtype: object

# %%
model = LogisticRegression()
model.fit(X_train_features, Y_train)
# Out:
# LogisticRegression()

# %%
prediction_on_training_data = model.predict(X_train_features)
accuracy_on_training_data = accuracy_score(Y_train, prediction_on_training_data)

print('Accuracy on training data : ', accuracy_on_training_data)
# Out:
# Accuracy on training data :  0.995164410058027

# %%
# prediction on test data

prediction_on_test_data = model.predict(X_test_features)
accuracy_on_test_data = accuracy_score(Y_test, prediction_on_test_data)

print('Accuracy on test data : ', accuracy_on_test_data)
# Out:
# Accuracy on test data :  0.991304347826087

# %%
input_mail = ["I've been searching for the right words to thank you for this breather. I promise i wont take your help for granted and will fulfil my promise. You have been wonderful and a blessing at all times"]

# convert text to feature vectors
input_data_features = feature_extraction.transform(input_mail)

# making prediction

prediction = model.predict(input_data_features)
print(prediction)


if (prediction[0]==1):
  print('Ham mail')

else:
  print('Spam mail')
# Out:
# [1]
# Ham mail
