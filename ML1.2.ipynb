# %% [markdown]
# Label Encodeing
# -Converting labels into numeric form

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#importing the libraries
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
# !kaggle datasets download -d yasserh/breast-cancer-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/yasserh/breast-cancer-dataset
# License(s): CC0-1.0
# ...
#   0% 0.00/48.6k [00:00<?, ?B/s]
# 100% 48.6k/48.6k [00:00<00:00, 46.0MB/s]

# %%
#Label encoding of Breast Cancer Dataset
#Loading the data from csv file to pandas dataframe
import zipfile
import os
dataset='/content/breast-cancer-dataset.zip'
extract='/content/sample_data'
with zipfile.ZipFile(dataset,'r') as zip_ref:
  zip_ref.extractall(extract)

# %%
data=pd.read_csv('/content/sample_data/breast-cancer.csv')

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
data['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %% [markdown]
# 0-> Benign
# 1-> Malignant

# %%
label_encode=LabelEncoder()

# %%
labels=label_encode.fit_transform(data.diagnosis)

# %%
#appending the target to dataframee
data["target"]=labels

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data['target'].value_counts()
# Out:
# target
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
#!/bin/bash
# !kaggle datasets download himanshunakrani/iris-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/himanshunakrani/iris-dataset
# License(s): CC0-1.0
# ...
#   0% 0.00/0.98k [00:00<?, ?B/s]
# 100% 0.98k/0.98k [00:00<00:00, 2.34MB/s]

# %%
import zipfile
import os
data_extract='/content/iris-dataset.zip'
extract_at='/content/sample_data'
with zipfile.ZipFile(data_extract,'r') as zip_ref:
  zip_ref.extractall(extract_at)

# %%
data=pd.read_csv('/content/sample_data/iris.csv')

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.shape
# Out:
# (150, 5)

# %%
data['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
label_encod=LabelEncoder()

# %%
labelu=label_encod.fit_transform(data.species)

# %%
data['target']=labelu

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  target
# 0           5.1          3.5           1.4          0.2  setosa       0
# 1           4.9          3.0           1.4          0.2  setosa       0
# 2           4.7          3.2           1.3          0.2  setosa       0
# 3           4.6          3.1           1.5          0.2  setosa       0
# 4           5.0          3.6           1.4          0.2  setosa       0

# %%
data['target'].value_counts()
# Out:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %% [markdown]
# Train_test_split

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Analysis
# PIMA Diabetes Dataset

# %%
#!/bin/bash
# !kaggle datasets download akshaydattatraykhare/diabetes-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/akshaydattatraykhare/diabetes-dataset
# License(s): CC0-1.0
# ...
#   0% 0.00/8.91k [00:00<?, ?B/s]
# 100% 8.91k/8.91k [00:00<00:00, 15.3MB/s]

# %%
import zipfile
import os
data='/content/diabetes-dataset.zip'
extract='/content/sample_data'
with zipfile.ZipFile(data,'r') as zip_ref:
  zip_ref.extractall(extract)

# %%
#loading the diabetes dataset to a pandas dataframe
diab=pd.read_csv('/content/sample_data/diabetes.csv')

# %%
diab.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diab.shape
# Out:
# (768, 9)

# %%
diab.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
diab['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
diab.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
X=diab.drop(columns='Outcome',axis=1)
Y=diab['Outcome']

# %%
print(X)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
print(Y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# Data Standardization

# %%
scaler=StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
StandardScaler(copy=True,with_mean=True,with_std=True)
# Out:
# StandardScaler()

# %%
standardized_data=scaler.transform(X)

# %%
print(standardized_data)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X=standardized_data
Y=diab['Outcome']

# %%
print(X)
print(Y)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# Spliitting the data into Training and Testing Data

# %%
X_train,X_test,Y_train,Y_test= train_test_split(X,Y,test_size=0.2,random_state=42)#random_state=42 → Ensures the same split every time you run the code.

# %%
print(X_train,X_test,Y_train,Y_test)
# Out:
# [[-0.54791859 -1.15469351 -3.57259724 ... -4.06047387 -0.50700636
#   -1.04154944]
#  [ 1.53084665 -0.27837344  0.66661825 ... -0.48135115  2.44666971
#    1.4259954 ]
#  [-0.84488505  0.56664949 -1.19450074 ... -0.41789153  0.55003518
#   -0.95646168]
#  ...
#  [ 1.82781311 -0.62264204  0.87340925 ...  1.72704372  2.00573238
#    0.40494237]
#  [-1.14185152  0.62924378 -3.57259724 ...  1.32090213 -0.8059981
#   -0.36084741]
#  [-1.14185152  0.12848945  1.39038675 ... -1.20479085 -0.63385134
#   -1.04154944]] [[ 0.63994726 -0.71653347 -0.57412775 ...  0.25478047 -0.1264714
#    0.83038113]
#  [-0.54791859 -0.27837344  0.304734   ...  0.47054319 -0.97814487
#   -1.04154944]
#  [-0.54791859 -0.40356202 -0.26394125 ... -0.15136112 -0.94794368
#   -1.04154944]
#  ...
#  [ 1.23388019 -0.81042491  0.14964075 ...  0.61015436  0.03963513
#    2.02160968]
#  [-0.54791859  0.7857295   0.04624525 ... -0.506735   -0.40734244
#   -0.36084741]
# ...

# %% [markdown]
# Imbalanced Dataset:
#
# A Dataset with an unequal class distribution

# %%
import numpy as np
import pandas as pd

# %%
#!/bin/bash
# !kaggle datasets download aryashah2k/credit-card-customer-data
# Out:
# Dataset URL: https://www.kaggle.com/datasets/aryashah2k/credit-card-customer-data
# License(s): CC0-1.0
# ...
#   0% 0.00/6.28k [00:00<?, ?B/s]
# 100% 6.28k/6.28k [00:00<00:00, 3.26MB/s]

# %%
import zipfile
import os
datass='/content/credit-card-customer-data.zip'
extru='/content/sample_data'
with zipfile.ZipFile(datass,'r') as zip_ref:
  zip_ref.extractall(extru)

# %%
c=pd.read_csv('/content/sample_data/Credit Card Customer Data.csv')

# %%
c.head()
# Out:
#    Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 0      1         87073            100000                   2
# 1      2         38414             50000                   3
# 2      3         17341             50000                   7
# 3      4         40496             30000                   5
# 4      5         47437            100000                   6
#
#    Total_visits_bank  Total_visits_online  Total_calls_made
# 0                  1                    1                 0
# 1                  0                   10                 9
# 2                  1                    3                 4
# 3                  1                    1                 4
# 4                  0                   12                 3

# %%
c['Total_calls_made'].value_counts()
# Out:
# Total_calls_made
# 4     108
# 0      97
# 2      91
# 1      90
# 3      83
# 6      39
# 7      35
# 9      32
# 8      30
# 5      29
# 10     26
# Name: count, dtype: int64

# %% [markdown]
# If it was Highly imbalanced Dataset

# %% [markdown]
# 0-->Legit Transaction
# 1-->Fraudulent Transaction

# %%
#Separating the Legit and Fraudelent Transaction
legit=c[c.Total_calls_made==0]
fraud=c[c.Total_calls_made==1]

# %%
print(legit)
print(fraud)
# Out:
#      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 0        1         87073            100000                   2
# 228    229         54838             10000                   7
# 232    233         83125             20000                   5
# 233    234         35483             13000                   7
# 235    236         83290             13000                   7
# ..     ...           ...               ...                 ...
# 645    646         48762            171000                  10
# 648    649         13315            111000                   8
# 652    653         28525            156000                   8
# 655    656         51108             99000                  10
# 658    659         80655            172000                  10
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 0                    1                    1                 0
# 228                  2                    0                 0
# ...

# %% [markdown]
# Under Sampling
# Build a sample dataset containing similar distribution of legit and fraudulent Transaction
# Number od Fraudelent Transaction=492

# %%
lefit_sample=legit.sample(n=49)

# %%
print(lefit_sample.shape)
# Out:
# (49, 7)

# %% [markdown]
# Concatenate the Two dataframe

# %%
new_dataframe=pd.concat([lefit_sample,fraud],axis=0)

# %% [markdown]
# About the dataset :
# 1. id: unique id for a news article
# 2. title: the title of a news article
# 3. author: author of the news article
# 4. text: the text of the article; could be incomplete
# 5. label: a label that marks whether the news article is real or fake: 1: Fake news 0: real News

# %%
import numpy as np
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True
